# %%
# %run RL_Trainer.py --gpu --name N_step --n 10 --plain-print
# Out:
# [2017-02-15 19:26:47,405] Making new env: Maze-2-v1
# ...
#                Settings:
# ...
#  t_max: 200000
#  env: Maze-2-v1
#  logdir: Logs
#  name: N_step
#  exp_replay_size: 10000
#  seed: 0
#  gpu: True
#  model: Maze-2
#  lr: 0.0001
#  exploration_steps: 100000
#  render: False
#  epsilon_steps: 150000
#  epsilon_start: 1.0
#  epsilon_finish: 0.1
#  batch_size: 64
#  gamma: 0.99
#  target: 100
#  count: False
#  beta: 0.1
#  n_step: 10
#  plain_print: True
# ...
#
# Logging to:
# Logs/N_step_2017-02-15_19-26
#
#
# Getting Models.
#
# Moving models to GPU.
#
# Exploratory phase for 100000 steps.
# Exploratory phase finished. Starting learning.
#
# Training.
#
#
#
# ...

# %%
batch = replay.Sample_N(args.batch_size, args.n_step, args.gamma)

# %%
acc = 0
for i in range(10):
    acc += env.negative_reward * (0.99 ** i)

# %%
acc
# Out:
# -0.016261551869250938

# %%
env.negative_reward
# Out:
# -0.0017006802721088435

# %%
batch[0]
# Out:
# (array([[[ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.        ],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.        ],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333]],
#
#         [[ 0.33333333],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.        ],
#          [ 0.33333333]],
#
#         [[ 0.33333333],
#          [ 0.        ],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.        ],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.33333333],
#          [ 0.        ],
#          [ 0.33333333],
# ...

# %%
len(batch)
# Out:
# 64

# %%
Episode_Rewards[-10:]
# Out:
# [0.0017006802721136664,
#  0.001700680272116109,
#  0.0017006802721184404,
#  0.0017006802721202168,
#  0.0017006802721198837,
#  0.0017006802721131113,
#  0.0017006802721142216,
#  0.0017006802721193286,
#  0.0017006802721231033,
#  0.0017006802721202168]
